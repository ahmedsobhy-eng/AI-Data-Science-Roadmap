# %% [markdown]
# # top five league players#

# %%
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv("players_data-2026_2027.csv")
df.tail()
# Out:
#         Rk            Player  Nation Pos         Squad                Comp  \
# 2029  2030  Martín Zubimendi  es ESP  MF       Arsenal  eng Premier League
# 2030  2031      Adam Zulevic  sk SVK  FW         Genoa          it Serie A
# 2031  2032   Martin Ødegaard  no NOR  MF       Arsenal  eng Premier League
# 2032  2033      Leo Østigård  no NOR  DF         Genoa          it Serie A
# 2033  2034        Luka Đurić  rs SRB  MF  Paderborn 07       de Bundesliga
#
#        Age    Born  MP  Starts  ...  CrdY_stats_misc  CrdR_stats_misc  2CrdY  \
# 2029  27.0  1999.0   4       0  ...                0                0      0
# 2030  19.0  2007.0   1       0  ...                0                0      0
# 2031  27.0  1998.0   4       4  ...                0                0      0
# 2032  26.0  1999.0   4       4  ...                3                0      0
# 2033  23.0  2003.0   1       0  ...                0                0      0
#
#       Fls  Fld  Off  Crs  Int  TklW  OG
# ...

# %%
print("Shape :",df.shape)
# Out:
# Shape : (2034, 102)

# %%
print(df.columns.to_list())
# Out:
# ['Rk', 'Player', 'Nation', 'Pos', 'Squad', 'Comp', 'Age', 'Born', 'MP', 'Starts', 'Min', '90s', 'Gls', 'Ast', 'G+A', 'G-PK', 'PK', 'PKatt', 'CrdY', 'CrdR', 'G+A-PK', 'Rk_stats_keeper', 'Nation_stats_keeper', 'Pos_stats_keeper', 'Comp_stats_keeper', 'Age_stats_keeper', 'Born_stats_keeper', 'MP_stats_keeper', 'Starts_stats_keeper', 'Min_stats_keeper', '90s_stats_keeper', 'GA', 'GA90', 'SoTA', 'Saves', 'Save%', 'W', 'D', 'L', 'CS', 'CS%', 'PKatt_stats_keeper', 'PKA', 'PKsv', 'PKm', 'Rk_stats_shooting', 'Nation_stats_shooting', 'Pos_stats_shooting', 'Comp_stats_shooting', 'Age_stats_shooting', 'Born_stats_shooting', '90s_stats_shooting', 'Gls_stats_shooting', 'Sh', 'SoT', 'SoT%', 'Sh/90', 'SoT/90', 'G/Sh', 'G/SoT', 'PK_stats_shooting', 'PKatt_stats_shooting', 'Rk_stats_playing_time', 'Nation_stats_playing_time', 'Pos_stats_playing_time', 'Comp_stats_playing_time', 'Age_stats_playing_time', 'Born_stats_playing_time', 'MP_stats_playing_time', 'Min_stats_playing_time', 'Mn/MP', 'Min%', '90s
# ...

# %%
missing_value=df.isnull().sum()
print(missing_value)
# Out:
# Rk        0
# Player    0
# Nation    3
# Pos       0
# Squad     0
#          ..
# Off       0
# Crs       0
# Int       0
# TklW      0
# OG        0
# Length: 102, dtype: int64

# %%
df.dropna(inplace=True)
print(df.isnull().sum())
# Out:
# Rk        0
# Player    0
# Nation    0
# Pos       0
# Squad     0
#          ..
# Off       0
# Crs       0
# Int       0
# TklW      0
# OG        0
# Length: 102, dtype: int64

# %%
duplicates_counts=df.duplicated().sum()
print("Number of duplicate rows:",duplicates_counts)
# Out:
# Number of duplicate rows: 0

# %%
numerical_columns = df.select_dtypes(include=["int64", "float64"]).columns
categorical_columns = df.select_dtypes(include=["category", "object"]).columns

print("Numerical columns count:", len(numerical_columns))
print("Categorical columns count:", len(categorical_columns))

print("\nCategorical columns are:")
print(categorical_columns.tolist())
# Out:
# Numerical columns count: 81
# Categorical columns count: 20
#
# Categorical columns are:
# ['Player', 'Nation', 'Squad', 'Comp', 'Nation_stats_keeper', 'Pos_stats_keeper', 'Comp_stats_keeper', 'Age_stats_keeper', 'Nation_stats_shooting', 'Pos_stats_shooting', 'Comp_stats_shooting', 'Age_stats_shooting', 'Nation_stats_playing_time', 'Pos_stats_playing_time', 'Comp_stats_playing_time', 'Age_stats_playing_time', 'Nation_stats_misc', 'Pos_stats_misc', 'Comp_stats_misc', 'Age_stats_misc']

# %%
df = pd.get_dummies(df, columns=["Pos"], dtype=int)

print(df.columns[-10:].tolist())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df = pd.get_dummies(df, columns=["Pos"], dtype=int)
#       3 print(df.columns[-10:].tolist())
#
# File c:\Users\Ahmed sobhy\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\encoding.py:170, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     168     raise TypeError("Input must be a list-like for parameter `columns`")
#     169 else:
# --> 170     data_to_encode = data[columns]
#     172 # validate prefixes and separator to avoid silently dropping cols
#     173 def check_len(item, name: str):
#
# File c:\Users\Ahmed sobhy\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111     if is_iterator(key):
#    4112         key = list(key)
# ...

# %%
print(df[['Player', 'Pos_FW', 'Pos_MF', 'Pos_DF', 'Pos_GK']].head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 print(df[['Player', 'Pos_FW', 'Pos_MF', 'Pos_DF', 'Pos_GK']].head())
#
# File c:\Users\Ahmed sobhy\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111     if is_iterator(key):
#    4112         key = list(key)
# -> 4113     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4115 # take() does not accept boolean indexers
#    4116 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\Ahmed sobhy\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
# ...

# %%
df['Goals_Per_Match']=df['Gls']/df['MP']
print(df[['Player','Goals_Per_Match','Gls','MP']].head(10))
# Out:
# Empty DataFrame
# Columns: [Player, Goals_Per_Match, Gls, MP]
# Index: []

# %%
# X: كل الإحصائيات (المعطيات) ما عدا الأهداف
# axis=1 معناها امسح العمود بالكامل مش الصف
X = df.drop("Gls", axis=1)

# y: عمود الأهداف بس (النتيجة اللي عاوزين نتوقعها)
y = df["Gls"]

# نطبع الأبعاد عشان نتأكد إن الفصل تم بنجاح
print("X shape (Features):", X.shape)
print("y shape (Target):", y.shape)
# Out:
# X shape (Features): (0, 101)
# y shape (Target): (0,)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

df = pd.read_csv("players_data-2026_2027.csv")

df.dropna(inplace=True)

numeric_df = df.select_dtypes(include=['number'])
X = numeric_df.drop("Gls", axis=1)
y = df["Gls"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

model = LinearRegression()
model.fit(X_train_scaled, y_train)

predictions = model.predict(X_test_scaled)

print("تم التدريب والتوقع بنجاح! 🎉")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 14
#      11 X = numeric_df.drop("Gls", axis=1)
#      12 y = df["Gls"]
# ---> 14 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
#      16 scaler = StandardScaler()
#      17 X_train_scaled = scaler.fit_transform(X_train)
#
# File c:\Users\Ahmed sobhy\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
# ...

# %%
print("X shape (Features):", X.shape)
print("y shape (Target):", y.shape)
# Out:
# X shape (Features): (0, 80)
# y shape (Target): (0,)
